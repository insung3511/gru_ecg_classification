# %%
# # 그래픽 카드 둘로 쓰기 (두개 있을때, 하나만 있다면 0)
# # gpu idx 를 0 또는 1 로 설정하시오
# import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"]="{}".format(1) # gpu idx

# %%
# 경로에 폴더가 없으면 폴더 만들기
import os

def createDirectory(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print("Error: Failed to create the directory.")

# %%
import wfdb.processing as wp
from tqdm import tqdm
import numpy as np
import itertools
import random
import wfdb

from sklearn.model_selection import train_test_split

from tensorflow.keras import layers
from tensorflow import keras
import tensorflow as tf

EPOCH = 200
KERNEL_SIZE = 3
POOLING_SIZE = 2
BATCH_SIZE = 128

DATA_PATH = "./pickle_rand/"

def list_to_list(input_list):
    input_list_to_list = list(itertools.chain(*input_list))
    return input_list_to_list

def zero_sum(x_array, y_array):
    x_return_array, y_return_array = [], []
    for i in range(len(x_array)):
        if np.sum(x_array[i]) == 0:
            continue
        else:
            x_return_array.append(x_array[i])
            y_return_array.append(y_array[i])
    return x_return_array, y_return_array

def flatter(list_of_list):
    flatList = [ item for elem in list_of_list for item in elem]
    return flatList

def TrainSetPadding(Xarray, Yarray):
    Xreturn, yreturn = [], []
    for i in range(len(Xarray)):
        beat_list = Xarray[i]
        beat_anno = Yarray[i]

        if np.sum(beat_list) == 0:
            continue

        if len(beat_list) >= 428:
            yreturn.append(beat_anno)
            Xreturn.append(beat_list[:428])
        
        else:
            random_front_add = np.random.randint(0, 428 - len(beat_list))
            random_back_add  = 428 - (random_front_add + len(beat_list))
            yreturn.append(beat_anno) 
            Xreturn.append(
                np.append([0.0], np.pad(beat_list, (random_front_add, random_back_add), 'constant', constant_values=0))[:428]
            )
        
    return np.array(Xreturn), np.array(yreturn)

def TestSetPadding(Xarray, Yarray):
    Xreturn, yreturn = [], []
    for i in range(len(Xarray)):
        beat_list = Xarray[i]
        beat_anno = Yarray[i]

        if np.sum(beat_list) == 0:
            continue

        if len(beat_list) > 428:
            yreturn.append(beat_anno)
            Xreturn.append(beat_list[:428])

        else:
            yreturn.append(beat_anno)
            cutting_off = int((428 - len(beat_list)) / 2)

            if len(np.pad(beat_list, cutting_off, 'constant', constant_values=0)) == 427:
                Xreturn.append(np.append([0.0], np.pad(beat_list, cutting_off, 'constant', constant_values=0)))

            else:
                Xreturn.append(np.pad(beat_list, cutting_off, 'constant', constant_values=0)[:428])
    return np.array(Xreturn), np.array(yreturn)    

def concater(normal, supra, ventri, fusion, q):
    return list(itertools.chain(normal, supra, ventri, fusion, q))

# %% [markdown]
# # 데이터 불러오기

# %%
# Cutting as a beat that just raw signal.
# That's it.

PICKLE_PATH = "./pickle_mat/"
DEFAULT_PATH = "./original_data/"
DB_PATH = ['mit']
EXTRA_NP = np.array(0)

NORAML_ANN = ['N', 'L', 'R', 'e', 'j']
SUPRA_ANN = ['A', 'a', 'J', 'S']
VENTRI_ANN = ['V', 'E']
FUSION_ANN = ['F']
UNCLASS_ANN = ['/', 'f', 'Q']

np.random.seed(42)

# - - - - - - - - - - - - - - - - - - - - - - - - - 
# Read only beats
R_PATH = DEFAULT_PATH + DB_PATH[0] + "/"

dict_ann = []
windowed_list = []
record_list = []
record_ann = []
longest = 0.

zero_padded_list = []

sigN, sigV, sigS, sigF, sigQ = [],[],[],[],[]
annN, annV, annS, annF, annQ = [],[],[],[],[]

# Read RECORDS txt file
print("[INFO] Read records file from ", R_PATH)
with open(R_PATH + 'RECORDS') as f:
    record_lines = f.readlines()

# Read Records
print("[INFO] Read RECORDS that what it read it")
for i in range(len(record_lines)):
    record_list.append(str(record_lines[i].strip()))

print("[INFO] Starting Cutting beat and make it shuffle as casino")
for j in tqdm(range(len(record_list))):
    temp_rpath = R_PATH + record_list[j]
    record_sg, _ = wfdb.rdsamp(temp_rpath, channels=[0], sampfrom=0)
    
    # Got R-R Peak by rdann funciton
    record_ann = list(wfdb.rdann(temp_rpath, 'atr', sampfrom=0).sample)[1:]
    record_ann_sym = list(wfdb.rdann(temp_rpath, 'atr', sampfrom=0).symbol)[1:]
    interval = wp.ann2rr(temp_rpath, 'atr', as_array=True)
    
    for i in range(len(record_ann)):            
        try:
            pre_add = record_ann[i - 1]
            post_add = record_ann[i + 1]
        except IndexError:
            pre_add = record_ann[i - 1]
            post_add = record_ann[-1]

        check_ann = record_ann_sym[i]
        avg_div = (interval[i - 1] + interval[i]) / 2 
        
        cut_pre_add = record_ann[i] - int((record_ann[i] - pre_add) / 2)
        cut_post_add = record_ann[i] + int((post_add - record_ann[i]) / 2) 
        
        cutted_beat = flatter(record_sg[cut_pre_add:cut_post_add])

        if check_ann in NORAML_ANN:         # Normal
            record_ann_sym[i] = 0
            sigN.append(cutted_beat)
            annN.append(record_ann_sym[i])

        elif check_ann in SUPRA_ANN:        # Supra-Ventricular
            record_ann_sym[i] = 1
            sigS.append(cutted_beat)
            annS.append(record_ann_sym[i])

        elif check_ann in VENTRI_ANN:       # Ventricular
            record_ann_sym[i] = 2
            sigV.append(cutted_beat)
            annV.append(record_ann_sym[i])

        elif check_ann in FUSION_ANN:       # Fusion
            record_ann_sym[i] = 3
            sigF.append(cutted_beat)
            annF.append(record_ann_sym[i])

        elif check_ann in UNCLASS_ANN:      # Unknown
            record_ann_sym[i] = 4
            sigQ.append(cutted_beat)
            annQ.append(record_ann_sym[i])

        else:
            continue
        
    dict_ann.append(record_ann_sym[i])

sigN, annN = zero_sum(sigN, annN)
sigS, annS = zero_sum(sigS, annS)
sigV, annV = zero_sum(sigV, annV)
sigF, annF = zero_sum(sigF, annF)
sigQ, annQ = zero_sum(sigQ, annQ)

sigN_ran = random.sample(sigN, 10000)
annN_ran = random.sample(annN, 10000)
sigN_np = np.array(sigN_ran)
annN_np = np.array(annN_ran)

sigS_np = np.array(sigS)
annS_np = np.array(annS)

sigV_np = np.array(sigV)
annV_np = np.array(annV)

sigF_np = np.array(sigF)
annF_np = np.array(annF)

sigQ_np = np.array(sigQ)
annQ_np = np.array(annQ)

Xtr_N, Xte_N, Ytr_N, Yte_N = train_test_split(sigN_np, annN_np, test_size=0.3, random_state=42, shuffle=True)
Xtr_S, Xte_S, Ytr_S, Yte_S = train_test_split(sigS_np, annS_np, test_size=0.3, random_state=42, shuffle=True)
Xtr_V, Xte_V, Ytr_V, Yte_V = train_test_split(sigV_np, annV_np, test_size=0.3, random_state=42, shuffle=True)
Xtr_F, Xte_F, Ytr_F, Yte_F = train_test_split(sigF_np, annF_np, test_size=0.3, random_state=42, shuffle=True)
Xtr_Q, Xte_Q, Ytr_Q, Yte_Q = train_test_split(sigQ_np, annQ_np, test_size=0.3, random_state=42, shuffle=True)

# - - - - - - - - - - - - - - - - - - - - -
# Under-sampling
# - - - - - - - - - - - - - - - - - - - - -
sigN_ran = random.sample(sorted(Xtr_N), 7000)
annN_ran = random.sample(sorted(Ytr_N), 7000)
Xtr_N = np.array(sigN_ran)
Ytr_N = np.array(annN_ran)

# - - - - - - - - - - - - - - - - - - - - -
# Over-sampling
# - - - - - - - - - - - - - - - - - - - - -
sigV_ran = []
annV_ran = []
for sig in range(7000):
    sigV_ran.append(random.choice(Xtr_V))
    annV_ran.append(random.choice(Ytr_V))
Xtr_V = np.array(sigV_ran)
Ytr_V = np.array(annV_ran)

# - - - - - - - - - - - - - - - - - - - - -
sigS_ran = []
annS_ran = []
for sig in range(7000):
    sigS_ran.append(random.choice(Xtr_S))
    annS_ran.append(random.choice(Ytr_S))
Xtr_S = np.array(sigS_ran)
Ytr_S = np.array(annS_ran)

# - - - - - - - - - - - - - - - - - - - - -
sigF_ran = []
annF_ran = []
for sig in range(7000):
    sigF_ran.append(random.choice(Xtr_F))
    annF_ran.append(random.choice(Ytr_F))
Xtr_F = np.array(sigF_ran)
Ytr_F = np.array(annF_ran)

# - - - - - - - - - - - - - - - - - - - - -
sigQ_ran = []
annQ_ran = []
for sig in range(7000):
    sigQ_ran.append(random.choice(Xtr_Q))
    annQ_ran.append(random.choice(Ytr_Q))
Xtr_Q = np.array(sigQ_ran)
Ytr_Q = np.array(annQ_ran)

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

print("- "*35)

Xtr_N, Ytr_N = TrainSetPadding(Xtr_N, Ytr_N)
Xte_N, Yte_N = TestSetPadding(Xte_N, Yte_N)
print("[SIZE]\t\tXtr_N : {}\t\tXte_N : {}\n\t\tYtr_N : {}\t\t\tYte_N : {}".format(Xtr_N.shape, Xte_N.shape, Ytr_N.shape, Yte_N.shape))
print("- "*35)

Xtr_S, Ytr_S = TrainSetPadding(Xtr_S, Ytr_S)
Xte_S, Yte_S = TestSetPadding(Xte_S, Yte_S)
print("[SIZE]\t\tXtr_S : {}\t\tXte_S : {}\n\t\tYtr_S : {}\t\t\tYte_S : {}".format(Xtr_S.shape, Xte_S.shape, Ytr_S.shape, Yte_S.shape))
print("- "*35)

Xtr_V, Ytr_V = TrainSetPadding(Xtr_V, Ytr_V)
Xte_V, Yte_V = TestSetPadding(Xte_V, Yte_V)
print("[SIZE]\t\tXtr_V : {}\t\tXte_V : {}\n\t\tYtr_V : {}\t\t\tYte_V : {}".format(Xtr_V.shape, Xte_V.shape, Ytr_V.shape, Yte_V.shape))
print("- "*35)

Xtr_F, Ytr_F = TrainSetPadding(Xtr_F, Ytr_F)
Xte_F, Yte_F = TestSetPadding(Xte_F, Yte_F)
print("[SIZE]\t\tXtr_F : {}\t\tXte_F : {}\n\t\tYtr_F : {}\t\t\tYte_F : {}".format(Xtr_F.shape, Xte_F.shape, Ytr_F.shape, Yte_F.shape))
print("- "*35)

Xtr_Q, Ytr_Q = TrainSetPadding(Xtr_Q, Ytr_Q)
Xte_Q, Yte_Q = TestSetPadding(Xte_Q, Yte_Q)
print("[SIZE]\t\tXtr_Q : {}\t\tXte_Q : {}\n\t\tYtr_Q : {}\t\t\tYte_Q : {}".format(Xtr_Q.shape, Xte_Q.shape, Ytr_Q.shape, Yte_Q.shape))
print("- "*35 + "\n")

print("- "*10 + "Final Train-Test split result " + "- "*10)
X_train = np.array(concater(Xtr_N, Xtr_S, Xtr_V, Xtr_F, Xtr_Q))
y_train = np.array(concater(Ytr_N, Ytr_S, Ytr_V, Ytr_F, Ytr_Q))
X_test  = np.array(concater(Xte_N, Xte_S, Xte_V, Xte_F, Xte_Q))
y_test  = np.array(concater(Yte_N, Yte_S, Yte_V, Yte_F, Yte_Q))
print("[SIZE]\t\tX_train : {}\t\t\tX_test : {}\n\t\ty_train : {}\t\t\ty_test : {}".format(X_train.shape, X_test.shape, y_train.shape, y_test.shape))
print("- "*35)
# Out:
# [INFO] Read records file from  ./original_data/mit/
# [INFO] Read RECORDS that what it read it
# [INFO] Starting Cutting beat and make it shuffle as casino
# 100%|██████████| 48/48 [00:38<00:00,  1.25it/s]
# C:\Users\user\AppData\Local\Temp\ipykernel_5784\3135822481.py:106: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   sigN_np = np.array(sigN_ran)
# C:\Users\user\AppData\Local\Temp\ipykernel_5784\3135822481.py:109: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   sigS_np = np.array(sigS)
# C:\Users\user\AppData\Local\Temp\ipykernel_5784\3135822481.py:112: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   sigV_np = np.array(sigV)
# C:\Users\user\AppData\Local\Temp\ipykernel_5784\3135822481.py:115: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   sigF_np = np.array(sigF)
# C:\Users\user\AppData\Local\Temp\ipykernel_5784\3135822481.py:118: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   sigQ_np = np.array(sigQ)
# C:\Users\user\AppData\Local\Temp\ipykernel_5784\3135822481.py:132: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   Xtr_N = np.array(sigN_ran)
# C:\Users\user\AppData\Local\Temp\ipykernel_5784\3135822481.py:143: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   Xtr_V = np.array(sigV_ran)
# C:\Users\user\AppData\Local\Temp\ipykernel_5784\3135822481.py:152: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   Xtr_S = np.array(sigS_ran)
# C:\Users\user\AppData\Local\Temp\ipykernel_5784\3135822481.py:161: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   Xtr_F = np.array(sigF_ran)
# C:\Users\user\AppData\Local\Temp\ipykernel_5784\3135822481.py:170: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   Xtr_Q = np.array(sigQ_ran)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# [SIZE]		Xtr_N : (7000, 428)		Xte_N : (3000, 428)
# 		Ytr_N : (7000,)			Yte_N : (3000,)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# [SIZE]		Xtr_S : (7000, 428)		Xte_S : (835, 428)
# 		Ytr_S : (7000,)			Yte_S : (835,)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# [SIZE]		Xtr_V : (7000, 428)		Xte_V : (2171, 428)
# 		Ytr_V : (7000,)			Yte_V : (2171,)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# [SIZE]		Xtr_F : (7000, 428)		Xte_F : (241, 428)
# 		Ytr_F : (7000,)			Yte_F : (241,)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# [SIZE]		Xtr_Q : (7000, 428)		Xte_Q : (2412, 428)
# 		Ytr_Q : (7000,)			Yte_Q : (2412,)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# - - - - - - - - - - Final Train-Test split result - - - - - - - - - -
# [SIZE]		X_train : (35000, 428)			X_test : (8659, 428)
# 		y_train : (35000,)			y_test : (8659,)
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=True)

X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.33, random_state=42, shuffle=True )

npx = np.array(X_train)
npy = np.array(y_train)
npx_vali = np.array(X_val)
npy_vali = np.array(y_val)
npx_test = np.array(X_test)
npy_test = np.array(y_test)

print("[SIZE]\t\tNpX lenght : {}\n\t\tNpY length : {}".format(npx.shape, npy.shape))
print("[SIZE]\t\tX_validation length : {}\n\t\ty_validation length : {}".format(npx_vali.shape, npy_vali.shape))
print("[SIZE]\t\tX_test length : {}\n\t\ty_test length : {}".format(npx_test.shape, npy_test.shape))
# Out:
# [SIZE]		NpX lenght : (35000, 428)
# 		NpY length : (35000,)
# [SIZE]		X_validation length : (2858, 428)
# 		y_validation length : (2858,)
# [SIZE]		X_test length : (5801, 428)
# 		y_test length : (5801,)

# %%
# 랜덤으로 뽑아서 뿌려보기

import matplotlib.pyplot as plt
import random
# %matplotlib inline

random.seed(42)

plt.figure(figsize=(30, 12))
plt.suptitle("random pal, per PAL", fontsize=18)
n = 0
for i in random.sample(range(6480), 16):
    ax = plt.subplot(5, 5, n+1)
    plt.plot(npx[i])
    ax.set_title(str(npy[i]))
    n+=1

# %% [markdown]
# # 모델 생성

# %%
lefms = keras.Sequential([
    layers.Conv1D(32, 3, padding='same', input_shape=(428, 1)),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),

    layers.Conv1D(64, 3, padding='same'),
    layers.Conv1D(64, 3, padding='same'),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),
    layers.MaxPool1D(pool_size=(2), strides=2),
    
    layers.Conv1D(64, 3, padding='same'),
    layers.Conv1D(64, 3, padding='same'),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),
    layers.MaxPool1D(pool_size=(2), strides=2),
    
    layers.Conv1D(128, 3, padding='same'),
    layers.Conv1D(128, 3, padding='same'),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),
    layers.MaxPool1D(pool_size=(2), strides=2),
    
    layers.Conv1D(128, 3, padding='same'),
    layers.Conv1D(128, 3, padding='same'),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),
    layers.MaxPool1D(pool_size=(2), strides=2),
    
    layers.Conv1D(256, 3, kernel_regularizer=tf.keras.regularizers.l2(0.01), padding='same'),
    layers.Conv1D(256, 3, kernel_regularizer=tf.keras.regularizers.l2(0.01), padding='same'),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),
    layers.MaxPool1D(pool_size=(2), strides=2),
    
    layers.Conv1D(256, 3, kernel_regularizer=tf.keras.regularizers.l2(0.01), padding='same'),
    layers.Conv1D(256, 3, kernel_regularizer=tf.keras.regularizers.l2(0.01), padding='same'),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),
    layers.MaxPool1D(pool_size=(2), strides=2),

    layers.Reshape((1, 1536)),
    layers.Dropout(0.5), # 기존 0.5
    layers.GRU(1536),
    layers.Dense(192, kernel_regularizer=tf.keras.regularizers.l2(0.01), activation='relu'), # 0.1 하고 0.01
    layers.Dense(5, activation='softmax')
])

# %%
lefms.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 428, 32)           128
#
#  batch_normalization (BatchN  (None, 428, 32)          128
#  ormalization)
#
#  activation (Activation)     (None, 428, 32)           0
#
#  conv1d_1 (Conv1D)           (None, 428, 64)           6208
#
#  conv1d_2 (Conv1D)           (None, 428, 64)           12352
#
#  batch_normalization_1 (Batc  (None, 428, 64)          256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 428, 64)           0
#
#  max_pooling1d (MaxPooling1D  (None, 214, 64)          0
#  )
#
#  conv1d_3 (Conv1D)           (None, 214, 64)           12352
#
#  conv1d_4 (Conv1D)           (None, 214, 64)           12352
#
#  batch_normalization_2 (Batc  (None, 214, 64)          256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 214, 64)           0
#
#  max_pooling1d_1 (MaxPooling  (None, 107, 64)          0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 107, 128)          24704
#
#  conv1d_6 (Conv1D)           (None, 107, 128)          49280
#
#  batch_normalization_3 (Batc  (None, 107, 128)         512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 107, 128)          0
#
#  max_pooling1d_2 (MaxPooling  (None, 53, 128)          0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 53, 128)           49280
#
#  conv1d_8 (Conv1D)           (None, 53, 128)           49280
#
#  batch_normalization_4 (Batc  (None, 53, 128)          512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 53, 128)           0
#
#  max_pooling1d_3 (MaxPooling  (None, 26, 128)          0
#  1D)
#
#  conv1d_9 (Conv1D)           (None, 26, 256)           98560
#
#  conv1d_10 (Conv1D)          (None, 26, 256)           196864
#
#  batch_normalization_5 (Batc  (None, 26, 256)          1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 26, 256)           0
#
#  max_pooling1d_4 (MaxPooling  (None, 13, 256)          0
#  1D)
#
#  conv1d_11 (Conv1D)          (None, 13, 256)           196864
#
#  conv1d_12 (Conv1D)          (None, 13, 256)           196864
#
#  batch_normalization_6 (Batc  (None, 13, 256)          1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 13, 256)           0
#
#  max_pooling1d_5 (MaxPooling  (None, 6, 256)           0
#  1D)
#
#  reshape (Reshape)           (None, 1, 1536)           0
#
#  dropout (Dropout)           (None, 1, 1536)           0
#
#  gru (GRU)                   (None, 1536)              14164992
#
#  dense (Dense)               (None, 192)               295104
#
#  dense_1 (Dense)             (None, 5)                 965
#
# =================================================================
# Total params: 15,369,861
# Trainable params: 15,368,005
# Non-trainable params: 1,856
# _________________________________________________________________

# %%
lefms.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
)

# %% [markdown]
# # train, test, validation data 나누기

# %%
# Train
X_train = tf.convert_to_tensor(npx)
X_train = tf.reshape(X_train, [-1, 428, 1])

y_train = tf.convert_to_tensor(npy)
y_train = tf.one_hot(y_train, 5)
y_train = tf.reshape(y_train, [-1, 5])
print("X_train shape : ",X_train.shape)
print("y_train shape : ",y_train.shape)

# Validation
X_vali = tf.convert_to_tensor(npx_vali)
X_vali = tf.reshape(X_vali, [-1, 428, 1])

y_vali = tf.convert_to_tensor(npy_vali)
y_vali = tf.one_hot(y_vali, 5)
y_vali = tf.reshape(y_vali, [-1, 5])


print("X_validation shape : ", X_vali.shape)
print("y_validation shape : ", y_vali.shape)

# Test
X_test = tf.convert_to_tensor(npx_test)
X_test = tf.reshape(X_test, [-1, 428, 1])

y_test = tf.convert_to_tensor(npy_test)
y_test = tf.one_hot(y_test, 5)
y_test = tf.reshape(y_test, [-1, 5])
print("X_test shape : ", X_test.shape)
print("y_test shape : ", y_test.shape)
# Out:
# X_train shape :  (35000, 428, 1)
# y_train shape :  (35000, 5)
# X_validation shape :  (2858, 428, 1)
# y_validation shape :  (2858, 5)
# X_test shape :  (5801, 428, 1)
# y_test shape :  (5801, 5)

# %% [markdown]
# ### 콜백 설정

# %%
# 콜백 설정
from keras.callbacks import EarlyStopping, ModelCheckpoint

outDir = './cheakpoint/random_lefms_model_reg_again/' # 이 경로에 best 모델이 저장된다.
model_names = outDir + 'weights-{val_accuracy:.4f}.h5'
def get_callbacks(patience = 50):
    
    earlystop = EarlyStopping(monitor='val_accuracy', min_delta=0.0001, patience=patience)
  
    model_checkpoint = ModelCheckpoint(model_names, monitor='val_accuracy', verbose=1, save_best_only=True, period = 1)
  
    # callbacks = [earlystop, model_checkpoint]     # earlystop 사용하고 싶으면 이거 풀고 아래꺼 주석 처리
    callbacks = [model_checkpoint]

    return callbacks

# %% [markdown]
# # 학습하기

# %%
callbacks = get_callbacks()

lefms_hist = lefms.fit(X_train,
                       y_train,
                       batch_size=BATCH_SIZE, 
                       epochs=EPOCH, 
                       validation_data=(X_vali, y_vali),
                       callbacks = [callbacks])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/200
# 274/274 [==============================] - ETA: 0s - loss: 2.4023 - accuracy: 0.8363
# Epoch 1: val_accuracy improved from -inf to 0.20364, saving model to ./cheakpoint/random_lefms_model_reg_again\weights-0.2036.h5
# 274/274 [==============================] - 26s 53ms/step - loss: 2.4023 - accuracy: 0.8363 - val_loss: 3.0805 - val_accuracy: 0.2036
# Epoch 2/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.3736 - accuracy: 0.9170
# Epoch 2: val_accuracy improved from 0.20364 to 0.86879, saving model to ./cheakpoint/random_lefms_model_reg_again\weights-0.8688.h5
# 274/274 [==============================] - 12s 43ms/step - loss: 0.3734 - accuracy: 0.9171 - val_loss: 0.5606 - val_accuracy: 0.8688
# Epoch 3/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.2932 - accuracy: 0.9362
# Epoch 3: val_accuracy did not improve from 0.86879
# 274/274 [==============================] - 11s 42ms/step - loss: 0.2934 - accuracy: 0.9361 - val_loss: 1.2734 - val_accuracy: 0.6165
# Epoch 4/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.2865 - accuracy: 0.9417
# Epoch 4: val_accuracy did not improve from 0.86879
# 274/274 [==============================] - 11s 42ms/step - loss: 0.2865 - accuracy: 0.9417 - val_loss: 0.9798 - val_accuracy: 0.7313
# Epoch 5/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.2687 - accuracy: 0.9477
# Epoch 5: val_accuracy improved from 0.86879 to 0.93387, saving model to ./cheakpoint/random_lefms_model_reg_again\weights-0.9339.h5
# 274/274 [==============================] - 12s 44ms/step - loss: 0.2686 - accuracy: 0.9477 - val_loss: 0.3088 - val_accuracy: 0.9339
# Epoch 6/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.2493 - accuracy: 0.9517
# Epoch 6: val_accuracy did not improve from 0.93387
# 274/274 [==============================] - 11s 42ms/step - loss: 0.2493 - accuracy: 0.9517 - val_loss: 1.1049 - val_accuracy: 0.6596
# Epoch 7/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.2359 - accuracy: 0.9555
# Epoch 7: val_accuracy did not improve from 0.93387
# 274/274 [==============================] - 11s 42ms/step - loss: 0.2358 - accuracy: 0.9555 - val_loss: 0.7612 - val_accuracy: 0.8373
# Epoch 8/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.2241 - accuracy: 0.9599
# Epoch 8: val_accuracy did not improve from 0.93387
# 274/274 [==============================] - 11s 42ms/step - loss: 0.2240 - accuracy: 0.9599 - val_loss: 0.3484 - val_accuracy: 0.9167
# Epoch 9/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.2204 - accuracy: 0.9609
# Epoch 9: val_accuracy improved from 0.93387 to 0.95031, saving model to ./cheakpoint/random_lefms_model_reg_again\weights-0.9503.h5
# 274/274 [==============================] - 12s 44ms/step - loss: 0.2203 - accuracy: 0.9610 - val_loss: 0.2551 - val_accuracy: 0.9503
# Epoch 10/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1940 - accuracy: 0.9673
# Epoch 10: val_accuracy did not improve from 0.95031
# 274/274 [==============================] - 11s 42ms/step - loss: 0.1940 - accuracy: 0.9673 - val_loss: 0.3750 - val_accuracy: 0.9255
# Epoch 11/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.2043 - accuracy: 0.9655
# Epoch 11: val_accuracy improved from 0.95031 to 0.96641, saving model to ./cheakpoint/random_lefms_model_reg_again\weights-0.9664.h5
# 274/274 [==============================] - 12s 45ms/step - loss: 0.2045 - accuracy: 0.9655 - val_loss: 0.2005 - val_accuracy: 0.9664
# Epoch 12/200
# 274/274 [==============================] - ETA: 0s - loss: 0.2034 - accuracy: 0.9671
# Epoch 12: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 42ms/step - loss: 0.2034 - accuracy: 0.9671 - val_loss: 0.2774 - val_accuracy: 0.9521
# Epoch 13/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1868 - accuracy: 0.9691
# Epoch 13: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 11s 42ms/step - loss: 0.1868 - accuracy: 0.9691 - val_loss: 2.3013 - val_accuracy: 0.5217
# Epoch 14/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1916 - accuracy: 0.9708
# Epoch 14: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 11s 42ms/step - loss: 0.1917 - accuracy: 0.9708 - val_loss: 0.3544 - val_accuracy: 0.9118
# Epoch 15/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1782 - accuracy: 0.9716
# Epoch 15: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 19s 68ms/step - loss: 0.1781 - accuracy: 0.9717 - val_loss: 0.2966 - val_accuracy: 0.9419
# Epoch 16/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1612 - accuracy: 0.9752
# Epoch 16: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 21s 76ms/step - loss: 0.1612 - accuracy: 0.9751 - val_loss: 0.1936 - val_accuracy: 0.9622
# Epoch 17/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1712 - accuracy: 0.9738
# Epoch 17: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 11s 41ms/step - loss: 0.1715 - accuracy: 0.9737 - val_loss: 0.4078 - val_accuracy: 0.9125
# Epoch 18/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 0.9756
# Epoch 18: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 11s 41ms/step - loss: 0.1705 - accuracy: 0.9756 - val_loss: 0.3132 - val_accuracy: 0.9181
# Epoch 19/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1599 - accuracy: 0.9764
# Epoch 19: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 11s 41ms/step - loss: 0.1599 - accuracy: 0.9764 - val_loss: 1.1852 - val_accuracy: 0.6116
# Epoch 20/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1569 - accuracy: 0.9774
# Epoch 20: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 11s 41ms/step - loss: 0.1569 - accuracy: 0.9775 - val_loss: 0.5305 - val_accuracy: 0.8845
# Epoch 21/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.9799
# Epoch 21: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 11s 42ms/step - loss: 0.1453 - accuracy: 0.9799 - val_loss: 0.2538 - val_accuracy: 0.9479
# Epoch 22/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1654 - accuracy: 0.9772
# Epoch 22: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 21s 76ms/step - loss: 0.1653 - accuracy: 0.9773 - val_loss: 0.2535 - val_accuracy: 0.9549
# Epoch 23/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1395 - accuracy: 0.9801
# Epoch 23: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 43ms/step - loss: 0.1395 - accuracy: 0.9801 - val_loss: 0.3763 - val_accuracy: 0.9181
# Epoch 24/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1646 - accuracy: 0.9767
# Epoch 24: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 11s 42ms/step - loss: 0.1645 - accuracy: 0.9768 - val_loss: 0.3868 - val_accuracy: 0.9251
# Epoch 25/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1445 - accuracy: 0.9814
# Epoch 25: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 42ms/step - loss: 0.1444 - accuracy: 0.9814 - val_loss: 0.2606 - val_accuracy: 0.9447
# Epoch 26/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1373 - accuracy: 0.9818
# Epoch 26: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 43ms/step - loss: 0.1374 - accuracy: 0.9817 - val_loss: 0.2425 - val_accuracy: 0.9601
# Epoch 27/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1317 - accuracy: 0.9815
# Epoch 27: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 43ms/step - loss: 0.1316 - accuracy: 0.9815 - val_loss: 0.4038 - val_accuracy: 0.8985
# Epoch 28/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.9827
# Epoch 28: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 15s 54ms/step - loss: 0.1377 - accuracy: 0.9827 - val_loss: 0.2344 - val_accuracy: 0.9531
# Epoch 29/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1218 - accuracy: 0.9853
# Epoch 29: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 44ms/step - loss: 0.1218 - accuracy: 0.9853 - val_loss: 0.2354 - val_accuracy: 0.9549
# Epoch 30/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1259 - accuracy: 0.9838
# Epoch 30: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1258 - accuracy: 0.9839 - val_loss: 0.3486 - val_accuracy: 0.9283
# Epoch 31/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9846
# Epoch 31: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1294 - accuracy: 0.9846 - val_loss: 0.4708 - val_accuracy: 0.8943
# Epoch 32/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1312 - accuracy: 0.9835
# Epoch 32: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1312 - accuracy: 0.9835 - val_loss: 0.2339 - val_accuracy: 0.9594
# Epoch 33/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1208 - accuracy: 0.9857
# Epoch 33: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1207 - accuracy: 0.9857 - val_loss: 0.1955 - val_accuracy: 0.9640
# Epoch 34/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1174 - accuracy: 0.9861
# Epoch 34: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1174 - accuracy: 0.9862 - val_loss: 0.7022 - val_accuracy: 0.8527
# Epoch 35/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9851
# Epoch 35: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1253 - accuracy: 0.9851 - val_loss: 0.8208 - val_accuracy: 0.7974
# Epoch 36/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1125 - accuracy: 0.9870
# Epoch 36: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1126 - accuracy: 0.9870 - val_loss: 1.4773 - val_accuracy: 0.6812
# Epoch 37/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1135 - accuracy: 0.9868
# Epoch 37: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1136 - accuracy: 0.9867 - val_loss: 0.3650 - val_accuracy: 0.9339
# Epoch 38/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1092 - accuracy: 0.9881
# Epoch 38: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1092 - accuracy: 0.9881 - val_loss: 0.4043 - val_accuracy: 0.9034
# Epoch 39/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1164 - accuracy: 0.9858
# Epoch 39: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 13s 46ms/step - loss: 0.1164 - accuracy: 0.9858 - val_loss: 0.4085 - val_accuracy: 0.9153
# Epoch 40/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0961 - accuracy: 0.9895
# Epoch 40: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 43ms/step - loss: 0.0961 - accuracy: 0.9895 - val_loss: 0.2209 - val_accuracy: 0.9566
# Epoch 41/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1089 - accuracy: 0.9879
# Epoch 41: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 43ms/step - loss: 0.1088 - accuracy: 0.9879 - val_loss: 0.6789 - val_accuracy: 0.8492
# Epoch 42/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1027 - accuracy: 0.9883
# Epoch 42: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 44ms/step - loss: 0.1027 - accuracy: 0.9883 - val_loss: 0.4003 - val_accuracy: 0.9031
# Epoch 43/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1036 - accuracy: 0.9887
# Epoch 43: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 44ms/step - loss: 0.1036 - accuracy: 0.9887 - val_loss: 2.0037 - val_accuracy: 0.6428
# Epoch 44/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1140 - accuracy: 0.9873
# Epoch 44: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1140 - accuracy: 0.9873 - val_loss: 0.4616 - val_accuracy: 0.8894
# Epoch 45/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9818
# Epoch 45: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 46ms/step - loss: 0.1979 - accuracy: 0.9818 - val_loss: 0.8457 - val_accuracy: 0.8219
# Epoch 46/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1449 - accuracy: 0.9866
# Epoch 46: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1449 - accuracy: 0.9866 - val_loss: 3.3381 - val_accuracy: 0.3474
# Epoch 47/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0706 - accuracy: 0.9916
# Epoch 47: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0706 - accuracy: 0.9916 - val_loss: 0.3597 - val_accuracy: 0.9153
# Epoch 48/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0874 - accuracy: 0.9900
# Epoch 48: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0873 - accuracy: 0.9900 - val_loss: 0.2313 - val_accuracy: 0.9552
# Epoch 49/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0951 - accuracy: 0.9894
# Epoch 49: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0951 - accuracy: 0.9894 - val_loss: 0.2047 - val_accuracy: 0.9622
# Epoch 50/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0819 - accuracy: 0.9904
# Epoch 50: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0819 - accuracy: 0.9904 - val_loss: 0.2889 - val_accuracy: 0.9454
# Epoch 51/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0892 - accuracy: 0.9904
# Epoch 51: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0891 - accuracy: 0.9904 - val_loss: 0.3350 - val_accuracy: 0.9164
# Epoch 52/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9910
# Epoch 52: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0831 - accuracy: 0.9910 - val_loss: 0.4792 - val_accuracy: 0.8933
# Epoch 53/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0872 - accuracy: 0.9913
# Epoch 53: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0871 - accuracy: 0.9913 - val_loss: 0.4239 - val_accuracy: 0.8961
# Epoch 54/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0767 - accuracy: 0.9919
# Epoch 54: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0767 - accuracy: 0.9919 - val_loss: 0.4919 - val_accuracy: 0.8936
# Epoch 55/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9896
# Epoch 55: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1033 - accuracy: 0.9896 - val_loss: 1.8318 - val_accuracy: 0.5903
# Epoch 56/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1049 - accuracy: 0.9890
# Epoch 56: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1050 - accuracy: 0.9890 - val_loss: 0.3620 - val_accuracy: 0.9307
# Epoch 57/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0716 - accuracy: 0.9928
# Epoch 57: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 46ms/step - loss: 0.0716 - accuracy: 0.9927 - val_loss: 0.1989 - val_accuracy: 0.9626
# Epoch 58/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0944 - accuracy: 0.9901
# Epoch 58: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0945 - accuracy: 0.9901 - val_loss: 0.2675 - val_accuracy: 0.9521
# Epoch 59/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0778 - accuracy: 0.9926
# Epoch 59: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0780 - accuracy: 0.9925 - val_loss: 0.2363 - val_accuracy: 0.9521
# Epoch 60/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1033 - accuracy: 0.9894
# Epoch 60: val_accuracy did not improve from 0.96641
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1032 - accuracy: 0.9894 - val_loss: 0.2502 - val_accuracy: 0.9545
# Epoch 61/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9915
# Epoch 61: val_accuracy improved from 0.96641 to 0.97376, saving model to ./cheakpoint/random_lefms_model_reg_again\weights-0.9738.h5
# 274/274 [==============================] - 13s 47ms/step - loss: 0.0801 - accuracy: 0.9915 - val_loss: 0.1754 - val_accuracy: 0.9738
# Epoch 62/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9906
# Epoch 62: val_accuracy did not improve from 0.97376
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0938 - accuracy: 0.9906 - val_loss: 3.8996 - val_accuracy: 0.3611
# Epoch 63/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0755 - accuracy: 0.9925
# Epoch 63: val_accuracy improved from 0.97376 to 0.97411, saving model to ./cheakpoint/random_lefms_model_reg_again\weights-0.9741.h5
# 274/274 [==============================] - 13s 47ms/step - loss: 0.0754 - accuracy: 0.9925 - val_loss: 0.1664 - val_accuracy: 0.9741
# Epoch 64/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9914
# Epoch 64: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0848 - accuracy: 0.9914 - val_loss: 0.3319 - val_accuracy: 0.9398
# Epoch 65/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0940 - accuracy: 0.9906
# Epoch 65: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0942 - accuracy: 0.9906 - val_loss: 0.1872 - val_accuracy: 0.9692
# Epoch 66/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0658 - accuracy: 0.9936
# Epoch 66: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 46ms/step - loss: 0.0658 - accuracy: 0.9937 - val_loss: 0.4218 - val_accuracy: 0.8996
# Epoch 67/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1015 - accuracy: 0.9909
# Epoch 67: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1015 - accuracy: 0.9909 - val_loss: 0.2185 - val_accuracy: 0.9524
# Epoch 68/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9938
# Epoch 68: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0609 - accuracy: 0.9938 - val_loss: 0.5704 - val_accuracy: 0.8957
# Epoch 69/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0757 - accuracy: 0.9932
# Epoch 69: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0756 - accuracy: 0.9932 - val_loss: 0.2506 - val_accuracy: 0.9493
# Epoch 70/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0772 - accuracy: 0.9926
# Epoch 70: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0772 - accuracy: 0.9926 - val_loss: 0.1571 - val_accuracy: 0.9734
# Epoch 71/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0852 - accuracy: 0.9915
# Epoch 71: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0851 - accuracy: 0.9915 - val_loss: 0.3128 - val_accuracy: 0.9241
# Epoch 72/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1024 - accuracy: 0.9898
# Epoch 72: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1024 - accuracy: 0.9898 - val_loss: 0.4464 - val_accuracy: 0.9094
# Epoch 73/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9938
# Epoch 73: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 46ms/step - loss: 0.0696 - accuracy: 0.9938 - val_loss: 0.2351 - val_accuracy: 0.9517
# Epoch 74/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0805 - accuracy: 0.9929
# Epoch 74: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0806 - accuracy: 0.9929 - val_loss: 0.7195 - val_accuracy: 0.8139
# Epoch 75/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1003 - accuracy: 0.9908
# Epoch 75: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 46ms/step - loss: 0.1002 - accuracy: 0.9907 - val_loss: 0.2099 - val_accuracy: 0.9713
# Epoch 76/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0539 - accuracy: 0.9955
# Epoch 76: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0540 - accuracy: 0.9955 - val_loss: 0.2755 - val_accuracy: 0.9458
# Epoch 77/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0748 - accuracy: 0.9929
# Epoch 77: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0748 - accuracy: 0.9929 - val_loss: 0.2851 - val_accuracy: 0.9493
# Epoch 78/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0801 - accuracy: 0.9925
# Epoch 78: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0802 - accuracy: 0.9925 - val_loss: 0.2903 - val_accuracy: 0.9493
# Epoch 79/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0696 - accuracy: 0.9932
# Epoch 79: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0697 - accuracy: 0.9932 - val_loss: 2.3337 - val_accuracy: 0.5843
# Epoch 80/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0851 - accuracy: 0.9934
# Epoch 80: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0851 - accuracy: 0.9934 - val_loss: 0.3698 - val_accuracy: 0.9111
# Epoch 81/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1042 - accuracy: 0.9899
# Epoch 81: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 13s 46ms/step - loss: 0.1043 - accuracy: 0.9899 - val_loss: 2.6241 - val_accuracy: 0.5504
# Epoch 82/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0758 - accuracy: 0.9947
# Epoch 82: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0759 - accuracy: 0.9946 - val_loss: 0.9411 - val_accuracy: 0.8020
# Epoch 83/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9932
# Epoch 83: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0696 - accuracy: 0.9932 - val_loss: 0.8540 - val_accuracy: 0.8439
# Epoch 84/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9948
# Epoch 84: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0577 - accuracy: 0.9948 - val_loss: 0.3242 - val_accuracy: 0.9216
# Epoch 85/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9930
# Epoch 85: val_accuracy did not improve from 0.97411
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0737 - accuracy: 0.9930 - val_loss: 0.5194 - val_accuracy: 0.8761
# Epoch 86/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.9904
# Epoch 86: val_accuracy improved from 0.97411 to 0.97481, saving model to ./cheakpoint/random_lefms_model_reg_again\weights-0.9748.h5
# 274/274 [==============================] - 13s 47ms/step - loss: 0.1026 - accuracy: 0.9904 - val_loss: 0.1654 - val_accuracy: 0.9748
# Epoch 87/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0596 - accuracy: 0.9942
# Epoch 87: val_accuracy did not improve from 0.97481
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0596 - accuracy: 0.9942 - val_loss: 0.2485 - val_accuracy: 0.9461
# Epoch 88/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0587 - accuracy: 0.9943
# Epoch 88: val_accuracy did not improve from 0.97481
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0587 - accuracy: 0.9943 - val_loss: 0.5422 - val_accuracy: 0.8954
# Epoch 89/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0686 - accuracy: 0.9938
# Epoch 89: val_accuracy did not improve from 0.97481
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0689 - accuracy: 0.9937 - val_loss: 2.0839 - val_accuracy: 0.6137
# Epoch 90/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9942
# Epoch 90: val_accuracy did not improve from 0.97481
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0739 - accuracy: 0.9942 - val_loss: 0.1769 - val_accuracy: 0.9717
# Epoch 91/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0928 - accuracy: 0.9926
# Epoch 91: val_accuracy did not improve from 0.97481
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0928 - accuracy: 0.9925 - val_loss: 0.4581 - val_accuracy: 0.9146
# Epoch 92/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.9962
# Epoch 92: val_accuracy did not improve from 0.97481
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0500 - accuracy: 0.9962 - val_loss: 0.1617 - val_accuracy: 0.9724
# Epoch 93/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9953
# Epoch 93: val_accuracy did not improve from 0.97481
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0534 - accuracy: 0.9953 - val_loss: 0.5108 - val_accuracy: 0.8961
# Epoch 94/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1099 - accuracy: 0.9901
# Epoch 94: val_accuracy did not improve from 0.97481
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1099 - accuracy: 0.9901 - val_loss: 0.3434 - val_accuracy: 0.9405
# Epoch 95/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0589 - accuracy: 0.9944
# Epoch 95: val_accuracy improved from 0.97481 to 0.97761, saving model to ./cheakpoint/random_lefms_model_reg_again\weights-0.9776.h5
# 274/274 [==============================] - 13s 47ms/step - loss: 0.0589 - accuracy: 0.9944 - val_loss: 0.1681 - val_accuracy: 0.9776
# Epoch 96/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9947
# Epoch 96: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0560 - accuracy: 0.9947 - val_loss: 0.7985 - val_accuracy: 0.8174
# Epoch 97/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9934
# Epoch 97: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0831 - accuracy: 0.9934 - val_loss: 0.2677 - val_accuracy: 0.9374
# Epoch 98/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0560 - accuracy: 0.9955
# Epoch 98: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0560 - accuracy: 0.9955 - val_loss: 0.2290 - val_accuracy: 0.9629
# Epoch 99/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9925
# Epoch 99: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0831 - accuracy: 0.9925 - val_loss: 1.7469 - val_accuracy: 0.6770
# Epoch 100/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0648 - accuracy: 0.9945
# Epoch 100: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0647 - accuracy: 0.9945 - val_loss: 0.1795 - val_accuracy: 0.9703
# Epoch 101/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0702 - accuracy: 0.9939
# Epoch 101: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0702 - accuracy: 0.9939 - val_loss: 1.3223 - val_accuracy: 0.7488
# Epoch 102/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9962
# Epoch 102: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0519 - accuracy: 0.9962 - val_loss: 0.5174 - val_accuracy: 0.9055
# Epoch 103/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0927 - accuracy: 0.9921
# Epoch 103: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0926 - accuracy: 0.9921 - val_loss: 0.2432 - val_accuracy: 0.9556
# Epoch 104/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0458 - accuracy: 0.9968
# Epoch 104: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0458 - accuracy: 0.9968 - val_loss: 0.1475 - val_accuracy: 0.9713
# Epoch 105/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9938
# Epoch 105: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0708 - accuracy: 0.9938 - val_loss: 0.3619 - val_accuracy: 0.9325
# Epoch 106/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0627 - accuracy: 0.9954
# Epoch 106: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0626 - accuracy: 0.9954 - val_loss: 0.1605 - val_accuracy: 0.9741
# Epoch 107/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0459 - accuracy: 0.9963
# Epoch 107: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0460 - accuracy: 0.9962 - val_loss: 4.0946 - val_accuracy: 0.4976
# Epoch 108/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.9931
# Epoch 108: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 44ms/step - loss: 0.0960 - accuracy: 0.9931 - val_loss: 0.2157 - val_accuracy: 0.9636
# Epoch 109/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0549 - accuracy: 0.9953
# Epoch 109: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0550 - accuracy: 0.9953 - val_loss: 0.2681 - val_accuracy: 0.9524
# Epoch 110/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9945
# Epoch 110: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0703 - accuracy: 0.9945 - val_loss: 0.1670 - val_accuracy: 0.9734
# Epoch 111/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0586 - accuracy: 0.9953
# Epoch 111: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0586 - accuracy: 0.9953 - val_loss: 0.4555 - val_accuracy: 0.9136
# Epoch 112/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9950
# Epoch 112: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0639 - accuracy: 0.9950 - val_loss: 0.3833 - val_accuracy: 0.9153
# Epoch 113/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0813 - accuracy: 0.9936
# Epoch 113: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0813 - accuracy: 0.9936 - val_loss: 0.3565 - val_accuracy: 0.9269
# Epoch 114/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0533 - accuracy: 0.9955
# Epoch 114: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0533 - accuracy: 0.9955 - val_loss: 1.0775 - val_accuracy: 0.7526
# Epoch 115/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9916
# Epoch 115: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 46ms/step - loss: 0.1054 - accuracy: 0.9916 - val_loss: 0.2307 - val_accuracy: 0.9626
# Epoch 116/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9959
# Epoch 116: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0551 - accuracy: 0.9959 - val_loss: 0.3420 - val_accuracy: 0.9262
# Epoch 117/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0560 - accuracy: 0.9949
# Epoch 117: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0561 - accuracy: 0.9949 - val_loss: 3.0066 - val_accuracy: 0.5903
# Epoch 118/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0777 - accuracy: 0.9944
# Epoch 118: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 46ms/step - loss: 0.0777 - accuracy: 0.9944 - val_loss: 0.1594 - val_accuracy: 0.9720
# Epoch 119/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9970
# Epoch 119: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0406 - accuracy: 0.9970 - val_loss: 0.2529 - val_accuracy: 0.9489
# Epoch 120/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0697 - accuracy: 0.9944
# Epoch 120: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 46ms/step - loss: 0.0697 - accuracy: 0.9944 - val_loss: 0.2842 - val_accuracy: 0.9535
# Epoch 121/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0521 - accuracy: 0.9969
# Epoch 121: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0524 - accuracy: 0.9968 - val_loss: 0.1584 - val_accuracy: 0.9741
# Epoch 122/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1057 - accuracy: 0.9917
# Epoch 122: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 46ms/step - loss: 0.1056 - accuracy: 0.9917 - val_loss: 0.2439 - val_accuracy: 0.9517
# Epoch 123/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9956
# Epoch 123: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0532 - accuracy: 0.9956 - val_loss: 1.0548 - val_accuracy: 0.7922
# Epoch 124/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 0.9948
# Epoch 124: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0623 - accuracy: 0.9948 - val_loss: 0.2122 - val_accuracy: 0.9664
# Epoch 125/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 0.9947
# Epoch 125: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0608 - accuracy: 0.9947 - val_loss: 0.2065 - val_accuracy: 0.9643
# Epoch 126/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9974
# Epoch 126: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0425 - accuracy: 0.9974 - val_loss: 0.2061 - val_accuracy: 0.9629
# Epoch 127/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0607 - accuracy: 0.9949
# Epoch 127: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0607 - accuracy: 0.9949 - val_loss: 0.2267 - val_accuracy: 0.9671
# Epoch 128/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0661 - accuracy: 0.9949
# Epoch 128: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0661 - accuracy: 0.9949 - val_loss: 0.2146 - val_accuracy: 0.9622
# Epoch 129/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0384 - accuracy: 0.9978
# Epoch 129: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0384 - accuracy: 0.9978 - val_loss: 0.3381 - val_accuracy: 0.9416
# Epoch 130/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0949 - accuracy: 0.9923
# Epoch 130: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0949 - accuracy: 0.9923 - val_loss: 0.3581 - val_accuracy: 0.9377
# Epoch 131/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0489 - accuracy: 0.9969
# Epoch 131: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0489 - accuracy: 0.9969 - val_loss: 0.2070 - val_accuracy: 0.9664
# Epoch 132/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9983
# Epoch 132: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0312 - accuracy: 0.9983 - val_loss: 0.5790 - val_accuracy: 0.8859
# Epoch 133/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0891 - accuracy: 0.9929
# Epoch 133: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 46ms/step - loss: 0.0890 - accuracy: 0.9929 - val_loss: 0.2668 - val_accuracy: 0.9500
# Epoch 134/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9965
# Epoch 134: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0458 - accuracy: 0.9965 - val_loss: 0.2451 - val_accuracy: 0.9619
# Epoch 135/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0813 - accuracy: 0.9931
# Epoch 135: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0813 - accuracy: 0.9931 - val_loss: 0.2425 - val_accuracy: 0.9580
# Epoch 136/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9968
# Epoch 136: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0509 - accuracy: 0.9968 - val_loss: 0.7811 - val_accuracy: 0.8562
# Epoch 137/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9978
# Epoch 137: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0437 - accuracy: 0.9978 - val_loss: 0.1733 - val_accuracy: 0.9727
# Epoch 138/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0505 - accuracy: 0.9965
# Epoch 138: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0505 - accuracy: 0.9965 - val_loss: 0.1910 - val_accuracy: 0.9675
# Epoch 139/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9937
# Epoch 139: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0779 - accuracy: 0.9937 - val_loss: 2.8901 - val_accuracy: 0.6491
# Epoch 140/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0704 - accuracy: 0.9957
# Epoch 140: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0703 - accuracy: 0.9957 - val_loss: 0.1622 - val_accuracy: 0.9724
# Epoch 141/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9955
# Epoch 141: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0516 - accuracy: 0.9955 - val_loss: 0.7561 - val_accuracy: 0.8509
# Epoch 142/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9951
# Epoch 142: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0639 - accuracy: 0.9951 - val_loss: 0.3751 - val_accuracy: 0.9426
# Epoch 143/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0461 - accuracy: 0.9965
# Epoch 143: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0462 - accuracy: 0.9965 - val_loss: 0.2930 - val_accuracy: 0.9426
# Epoch 144/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0516 - accuracy: 0.9964
# Epoch 144: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0516 - accuracy: 0.9964 - val_loss: 0.2360 - val_accuracy: 0.9657
# Epoch 145/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0823 - accuracy: 0.9942
# Epoch 145: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0822 - accuracy: 0.9942 - val_loss: 0.1606 - val_accuracy: 0.9724
# Epoch 146/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9962
# Epoch 146: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 44ms/step - loss: 0.0497 - accuracy: 0.9962 - val_loss: 0.2201 - val_accuracy: 0.9685
# Epoch 147/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0549 - accuracy: 0.9967
# Epoch 147: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0548 - accuracy: 0.9967 - val_loss: 0.2144 - val_accuracy: 0.9605
# Epoch 148/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0496 - accuracy: 0.9956
# Epoch 148: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0497 - accuracy: 0.9956 - val_loss: 1.0726 - val_accuracy: 0.7719
# Epoch 149/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0748 - accuracy: 0.9946
# Epoch 149: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 44ms/step - loss: 0.0747 - accuracy: 0.9946 - val_loss: 1.0934 - val_accuracy: 0.7211
# Epoch 150/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9972
# Epoch 150: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0462 - accuracy: 0.9972 - val_loss: 0.1467 - val_accuracy: 0.9741
# Epoch 151/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 0.9961
# Epoch 151: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0553 - accuracy: 0.9961 - val_loss: 0.4069 - val_accuracy: 0.9171
# Epoch 152/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0680 - accuracy: 0.9952
# Epoch 152: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 44ms/step - loss: 0.0680 - accuracy: 0.9952 - val_loss: 0.3545 - val_accuracy: 0.9405
# Epoch 153/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9956
# Epoch 153: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0592 - accuracy: 0.9956 - val_loss: 0.6643 - val_accuracy: 0.8562
# Epoch 154/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0621 - accuracy: 0.9962
# Epoch 154: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0620 - accuracy: 0.9962 - val_loss: 0.7052 - val_accuracy: 0.8677
# Epoch 155/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9971
# Epoch 155: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0376 - accuracy: 0.9971 - val_loss: 0.6303 - val_accuracy: 0.8632
# Epoch 156/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1053 - accuracy: 0.9937
# Epoch 156: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.1052 - accuracy: 0.9937 - val_loss: 0.2146 - val_accuracy: 0.9678
# Epoch 157/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9981
# Epoch 157: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0349 - accuracy: 0.9981 - val_loss: 0.9909 - val_accuracy: 0.7873
# Epoch 158/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0602 - accuracy: 0.9948
# Epoch 158: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0603 - accuracy: 0.9948 - val_loss: 1.3349 - val_accuracy: 0.7866
# Epoch 159/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9959
# Epoch 159: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0642 - accuracy: 0.9959 - val_loss: 0.2212 - val_accuracy: 0.9615
# Epoch 160/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9974
# Epoch 160: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0409 - accuracy: 0.9974 - val_loss: 0.3065 - val_accuracy: 0.9528
# Epoch 161/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9944
# Epoch 161: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 44ms/step - loss: 0.0733 - accuracy: 0.9944 - val_loss: 0.2109 - val_accuracy: 0.9689
# Epoch 162/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9981
# Epoch 162: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0323 - accuracy: 0.9981 - val_loss: 0.3991 - val_accuracy: 0.9024
# Epoch 163/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0583 - accuracy: 0.9963
# Epoch 163: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 46ms/step - loss: 0.0583 - accuracy: 0.9963 - val_loss: 1.2130 - val_accuracy: 0.7638
# Epoch 164/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0769 - accuracy: 0.9946
# Epoch 164: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0769 - accuracy: 0.9946 - val_loss: 0.2327 - val_accuracy: 0.9594
# Epoch 165/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0429 - accuracy: 0.9973
# Epoch 165: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0429 - accuracy: 0.9973 - val_loss: 0.3118 - val_accuracy: 0.9461
# Epoch 166/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0871 - accuracy: 0.9938
# Epoch 166: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 44ms/step - loss: 0.0870 - accuracy: 0.9938 - val_loss: 0.2256 - val_accuracy: 0.9605
# Epoch 167/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9988
# Epoch 167: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0293 - accuracy: 0.9988 - val_loss: 0.1847 - val_accuracy: 0.9692
# Epoch 168/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0871 - accuracy: 0.9931
# Epoch 168: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0870 - accuracy: 0.9931 - val_loss: 0.1962 - val_accuracy: 0.9710
# Epoch 169/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9976
# Epoch 169: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0385 - accuracy: 0.9976 - val_loss: 0.2802 - val_accuracy: 0.9538
# Epoch 170/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0397 - accuracy: 0.9969
# Epoch 170: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0397 - accuracy: 0.9969 - val_loss: 2.4790 - val_accuracy: 0.6099
# Epoch 171/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0683 - accuracy: 0.9956
# Epoch 171: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0683 - accuracy: 0.9956 - val_loss: 0.3033 - val_accuracy: 0.9510
# Epoch 172/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9985
# Epoch 172: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0284 - accuracy: 0.9985 - val_loss: 0.2071 - val_accuracy: 0.9587
# Epoch 173/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0728 - accuracy: 0.9948
# Epoch 173: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0727 - accuracy: 0.9948 - val_loss: 0.6116 - val_accuracy: 0.8803
# Epoch 174/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0493 - accuracy: 0.9969
# Epoch 174: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0493 - accuracy: 0.9969 - val_loss: 0.6150 - val_accuracy: 0.8786
# Epoch 175/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0293 - accuracy: 0.9981
# Epoch 175: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0293 - accuracy: 0.9981 - val_loss: 0.1985 - val_accuracy: 0.9706
# Epoch 176/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0867 - accuracy: 0.9941
# Epoch 176: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0867 - accuracy: 0.9941 - val_loss: 0.7883 - val_accuracy: 0.8097
# Epoch 177/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9980
# Epoch 177: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0373 - accuracy: 0.9980 - val_loss: 0.4826 - val_accuracy: 0.8915
# Epoch 178/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0609 - accuracy: 0.9954
# Epoch 178: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0609 - accuracy: 0.9954 - val_loss: 0.5844 - val_accuracy: 0.8943
# Epoch 179/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0481 - accuracy: 0.9973
# Epoch 179: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0480 - accuracy: 0.9973 - val_loss: 0.1560 - val_accuracy: 0.9731
# Epoch 180/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0646 - accuracy: 0.9954
# Epoch 180: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0646 - accuracy: 0.9953 - val_loss: 0.4308 - val_accuracy: 0.9052
# Epoch 181/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0618 - accuracy: 0.9957
# Epoch 181: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0618 - accuracy: 0.9957 - val_loss: 0.8393 - val_accuracy: 0.8800
# Epoch 182/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0649 - accuracy: 0.9954
# Epoch 182: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0649 - accuracy: 0.9954 - val_loss: 0.1673 - val_accuracy: 0.9734
# Epoch 183/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0363 - accuracy: 0.9976
# Epoch 183: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0363 - accuracy: 0.9976 - val_loss: 0.3013 - val_accuracy: 0.9482
# Epoch 184/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0731 - accuracy: 0.9948
# Epoch 184: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0731 - accuracy: 0.9948 - val_loss: 0.9574 - val_accuracy: 0.7610
# Epoch 185/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9975
# Epoch 185: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0529 - accuracy: 0.9975 - val_loss: 0.1736 - val_accuracy: 0.9661
# Epoch 186/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0425 - accuracy: 0.9965
# Epoch 186: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0426 - accuracy: 0.9965 - val_loss: 1.2641 - val_accuracy: 0.7974
# Epoch 187/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0519 - accuracy: 0.9971
# Epoch 187: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0519 - accuracy: 0.9971 - val_loss: 0.1686 - val_accuracy: 0.9741
# Epoch 188/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9978
# Epoch 188: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0339 - accuracy: 0.9978 - val_loss: 13.0188 - val_accuracy: 0.3369
# Epoch 189/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9939
# Epoch 189: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.1010 - accuracy: 0.9939 - val_loss: 0.1718 - val_accuracy: 0.9752
# Epoch 190/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9979
# Epoch 190: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 46ms/step - loss: 0.0315 - accuracy: 0.9979 - val_loss: 0.1977 - val_accuracy: 0.9678
# Epoch 191/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.1811 - accuracy: 0.9863
# Epoch 191: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.1813 - accuracy: 0.9863 - val_loss: 0.8158 - val_accuracy: 0.8618
# Epoch 192/200
# 274/274 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9956
# Epoch 192: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.1244 - accuracy: 0.9956 - val_loss: 0.2135 - val_accuracy: 0.9650
# Epoch 193/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.9988
# Epoch 193: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0426 - accuracy: 0.9988 - val_loss: 0.2409 - val_accuracy: 0.9535
# Epoch 194/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9979
# Epoch 194: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0382 - accuracy: 0.9979 - val_loss: 0.1758 - val_accuracy: 0.9706
# Epoch 195/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9990
# Epoch 195: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0257 - accuracy: 0.9990 - val_loss: 0.2089 - val_accuracy: 0.9619
# Epoch 196/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0617 - accuracy: 0.9952
# Epoch 196: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 12s 45ms/step - loss: 0.0617 - accuracy: 0.9952 - val_loss: 0.2165 - val_accuracy: 0.9675
# Epoch 197/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0325 - accuracy: 0.9981
# Epoch 197: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0325 - accuracy: 0.9981 - val_loss: 0.1915 - val_accuracy: 0.9671
# Epoch 198/200
# 273/274 [============================>.] - ETA: 0s - loss: 0.0299 - accuracy: 0.9981
# Epoch 198: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0299 - accuracy: 0.9981 - val_loss: 1.0234 - val_accuracy: 0.7390
# Epoch 199/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9953
# Epoch 199: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0643 - accuracy: 0.9953 - val_loss: 0.2285 - val_accuracy: 0.9601
# Epoch 200/200
# 274/274 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9970
# Epoch 200: val_accuracy did not improve from 0.97761
# 274/274 [==============================] - 13s 46ms/step - loss: 0.0416 - accuracy: 0.9970 - val_loss: 0.4114 - val_accuracy: 0.9300

# %% [markdown]
# # 결과 시각화 하기

# %%
# 학습 된 모델의 학습 과정 시각화
import matplotlib.pyplot as plt
def plot_model__hist(hist):
    path = './cheakpoint/lefms/' # loss, accuracy 그래프 저장할 path
    createDirectory(path)

    # loss 추이 그래프로 그려서 저장
    plt.figure(figsize=(6,6))
    plt.style.use("ggplot")
    plt.plot(hist.history['loss'], color='b', label="Training loss")
    plt.plot(hist.history['val_loss'], color='r', label="Validation loss")
    plt.savefig(path + 'model_loss_hist.png')
    plt.legend()
    plt.show()

    # accuracy 추이 그래프로 그려서 저장
    plt.figure(figsize=(6,6))
    plt.style.use("ggplot")
    plt.plot(hist.history['accuracy'], color='b', label="Training accuracy")
    plt.plot(hist.history['val_accuracy'], color='r',label="Validation accuracy")
    plt.savefig(path + 'model_loss_hist.png')
    plt.legend(loc = "lower right")
    plt.show()

# %%
plot_model__hist(lefms_hist)
loss,acc = lefms.evaluate(X_test, y_test, verbose=2)
print("multi_model의 정확도: {:5.2f}%".format(100*acc))
print("multi_model의 Loss: {}".format(loss))
# Out:
# 182/182 - 2s - loss: 0.4289 - accuracy: 0.9190 - 2s/epoch - 13ms/step
# multi_model의 정확도: 91.90%
# multi_model의 Loss: 0.4288956820964813

# %% [markdown]
# # 모델 불러와서 confusion matrix 그리기

# %%
# 모델 불러오기
reconstructed_model = keras.models.load_model("./cheakpoint/random_lefms_model_reg_again/weights-0.9776.h5")

# %%
# 예측값 얻기
y_pred = reconstructed_model.predict(X_test)
# Out:
# 182/182 [==============================] - 3s 10ms/step

# %%
# one hat encoding 를 하나의 변수로 바꾸기
new_y= []
for val in y_test:
    max = 0
    cnt = 0
    for idx, num in enumerate(val):
        if max < num:
            max = num
            cnt = idx + 1
    new_y.append(cnt)

# %%
# one hat encoding 를 하나의 변수로 바꾸기
new_y_pred = []
for val in y_pred:
    max = 0
    cnt = 0
    for idx, num in enumerate(val):
        if max < num:
            max = num
            cnt = idx + 1
    new_y_pred.append(cnt)

# %%
# 최종 정확도 산출
score = reconstructed_model.evaluate(X_test, y_test, verbose=1)
print('정답률 = ', score[1],'loss=', score[0])
# Out:
# 182/182 [==============================] - 4s 13ms/step - loss: 0.1858 - accuracy: 0.9710
# 정답률 =  0.9710394740104675 loss= 0.18579351902008057

# %% [markdown]
# ### confusion matrix 그리기

# %%
# 개수 버전
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns

cm2 = confusion_matrix(new_y, new_y_pred)
sns.heatmap(cm2, annot = True, fmt = 'd', cmap= 'Reds')
plt.xlabel('predict')
plt.ylabel('real')
plt.xticks([0.5, 1.5, 2.5, 3.5, 4.5], ['0 = N', '1 = S', '2 = V', '3 = F', '4 = Q'])
plt.yticks([0.5, 1.5, 2.5, 3.5, 4.5], ['0 = N', '1 = S', '2 = V', '3 = F', '4 = Q'])
plt.show()

# %%
# percentile 버전
total = np.sum(cm2, axis=1)
cm2_percentile = cm2/total[:,None]
sns.heatmap(np.round(cm2_percentile,3), annot = True, cmap= 'Reds')
plt.xlabel('predict')
plt.ylabel('real')
plt.xticks([0.5, 1.5, 2.5, 3.5, 4.5], ['0 = N', '1 = S', '2 = V', '3 = F', '4 = Q'])
plt.yticks([0.5, 1.5, 2.5, 3.5, 4.5], ['0 = N', '1 = S', '2 = V', '3 = F', '4 = Q'])
plt.show()

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(new_y, new_y_pred)
# Out:
# array([[1938,   25,   10,   14,    2],
#        [  42,  521,    3,    2,    0],
#        [  16,    8, 1439,   16,    1],
#        [  11,    0,   10,  141,    0],
#        [   6,    0,    1,    1, 1594]], dtype=int64)

# %%
# classification_report 그리기
from sklearn.metrics import classification_report
target_names = ['0 = N', '1 = S', '2 = V', '3 = F', '4 = Q']
print(classification_report(new_y, new_y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#        0 = N       0.96      0.97      0.97      1989
#        1 = S       0.94      0.92      0.93       568
#        2 = V       0.98      0.97      0.98      1480
#        3 = F       0.81      0.87      0.84       162
#        4 = Q       1.00      1.00      1.00      1602
#
#     accuracy                           0.97      5801
#    macro avg       0.94      0.95      0.94      5801
# weighted avg       0.97      0.97      0.97      5801
