# %%
import numpy as np
import itertools
import pickle
import os

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical,plot_model
from sklearn.preprocessing import LabelEncoder
from scipy import io


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn import preprocessing

from tensorflow.keras import layers
from tensorflow import keras
import tensorflow as tf
from tqdm import tqdm

EPOCH = 200
KERNEL_SIZE = 3
POOLING_SIZE = 2
BATCH_SIZE = 128

DATA_PATH = "./mit_data_3/mitSigP_NBRR.mat"

def list_to_list(input_list):
    input_list_to_list = list(itertools.chain(*input_list))
    return input_list_to_list

# 그래픽 카드 둘로 쓰기 (두개 있을때, 하나만 있다면 0)
# gpu idx 를 0 또는 1 로 설정하시오
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="{}".format(1) # gpu idx

# 경로에 폴더가 없으면 폴더 만들기
def createDirectory(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print("Error: Failed to create the directory.")

# %% [markdown]
# # 데이터 불러오기

# %%
# `# Dataload part
# le = preprocessing.LabelEncoder()

# record_list = []
# pickle_input = dict()
# X, y = [], []

# load mit data
x = io.loadmat(DATA_PATH)
x = x['mit_NBRR']
df = pd.DataFrame(data=x)

X = np.array(df[list(range(428))].values)[..., np.newaxis]
y = np.array(df[428].values).astype(np.int8)

oneHot = LabelEncoder()
oneHot.fit(y)
Y = oneHot.transform(y)

X = X.reshape(-1, 428, 1)
y = to_categorical(y, 5)

# %%
# 데이터 갯수 파악
# N, S, V, F, Q
uni, cnt = np.unique(y, return_counts=True)
print(uni, cnt)
# Out:
# [0. 1.] [437540 109385]

# %% [markdown]
# # 데이터 split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=True)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.33, random_state=42, shuffle=True )

npx = np.array(X_train)
npy = np.array(y_train)
npx_vali = np.array(X_val)
npy_vali = np.array(y_val)
npx_test = np.array(X_test)
npy_test = np.array(y_test)

print("[SIZE]\t\tNpX lenght : {}\n\t\tNpY length : {}".format(npx.shape, npy.shape))
print("[SIZE]\t\tX_validation length : {}\n\t\ty_validation length : {}".format(npx_vali.shape, npy_vali.shape))
print("[SIZE]\t\tX_test length : {}\n\t\ty_test length : {}".format(npx_test.shape, npy_test.shape))
# Out:
# [SIZE]		NpX lenght : (73287, 428, 1)
# 		NpY length : (73287, 5)
# [SIZE]		X_validation length : (11913, 428, 1)
# 		y_validation length : (11913, 5)
# [SIZE]		X_test length : (24185, 428, 1)
# 		y_test length : (24185, 5)

# %%
uni, cnt = np.unique(npy, return_counts=True)
print(uni, cnt)
# Out:
# [0. 1.] [293148  73287]

# %%
uni, cnt = np.unique(npy_vali, return_counts=True)
print(uni, cnt)
# Out:
# [0. 1.] [47652 11913]

# %%
uni, cnt = np.unique(npy_test, return_counts=True)
print(uni, cnt)
# Out:
# [0. 1.] [96740 24185]

# %%
# 랜덤으로 뽑아서 뿌려보기

import matplotlib.pyplot as plt
import random
# %matplotlib inline

plt.figure(figsize=(30, 12))
plt.suptitle("random pal, per PAL", fontsize=18)
n = 0
random.seed(11)
for i in random.sample(range(6480), 16):
    ax = plt.subplot(5, 5, n+1)
    plt.plot(npx[i])
    ax.set_title(str(npy[i]))
    n+=1

# %% [markdown]
# # 모델 생성

# %%
lefms = keras.Sequential([
    layers.Conv1D(32, 3, padding='same', input_shape=(428, 1)),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),

    layers.Conv1D(64, 3, padding='same'),
    layers.Conv1D(64, 3, padding='same'),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),
    layers.MaxPool1D(pool_size=(2), strides=2),
    
    layers.Conv1D(64, 3, padding='same'),
    layers.Conv1D(64, 3, padding='same'),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),
    layers.MaxPool1D(pool_size=(2), strides=2),
    
    layers.Conv1D(128, 3, padding='same'),
    layers.Conv1D(128, 3, padding='same'),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),
    layers.MaxPool1D(pool_size=(2), strides=2),
    
    layers.Conv1D(128, 3, padding='same'),
    layers.Conv1D(128, 3, padding='same'),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),
    layers.MaxPool1D(pool_size=(2), strides=2),
    
    layers.Conv1D(256, 3, padding='same'),
    layers.Conv1D(256, 3, padding='same'),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),
    layers.MaxPool1D(pool_size=(2), strides=2),
    
    layers.Conv1D(256, 3, padding='same'),
    layers.Conv1D(256, 3, padding='same'),
    layers.BatchNormalization(),
    layers.Activation(keras.activations.relu),
    layers.MaxPool1D(pool_size=(2), strides=2),

    layers.Reshape((1, 1536)),
    layers.Dropout(0.5),
    layers.GRU(1536),
    layers.Dense(192, activation='relu'),
    layers.Dense(5, activation='softmax')
])

# %%
lefms.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 428, 32)           128
#
#  batch_normalization (BatchN  (None, 428, 32)          128
#  ormalization)
#
#  activation (Activation)     (None, 428, 32)           0
#
#  conv1d_1 (Conv1D)           (None, 428, 64)           6208
#
#  conv1d_2 (Conv1D)           (None, 428, 64)           12352
#
#  batch_normalization_1 (Batc  (None, 428, 64)          256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 428, 64)           0
#
#  max_pooling1d (MaxPooling1D  (None, 214, 64)          0
#  )
#
#  conv1d_3 (Conv1D)           (None, 214, 64)           12352
#
#  conv1d_4 (Conv1D)           (None, 214, 64)           12352
#
#  batch_normalization_2 (Batc  (None, 214, 64)          256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 214, 64)           0
#
#  max_pooling1d_1 (MaxPooling  (None, 107, 64)          0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 107, 128)          24704
#
#  conv1d_6 (Conv1D)           (None, 107, 128)          49280
#
#  batch_normalization_3 (Batc  (None, 107, 128)         512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 107, 128)          0
#
#  max_pooling1d_2 (MaxPooling  (None, 53, 128)          0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 53, 128)           49280
#
#  conv1d_8 (Conv1D)           (None, 53, 128)           49280
#
#  batch_normalization_4 (Batc  (None, 53, 128)          512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 53, 128)           0
#
#  max_pooling1d_3 (MaxPooling  (None, 26, 128)          0
#  1D)
#
#  conv1d_9 (Conv1D)           (None, 26, 256)           98560
#
#  conv1d_10 (Conv1D)          (None, 26, 256)           196864
#
#  batch_normalization_5 (Batc  (None, 26, 256)          1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 26, 256)           0
#
#  max_pooling1d_4 (MaxPooling  (None, 13, 256)          0
#  1D)
#
#  conv1d_11 (Conv1D)          (None, 13, 256)           196864
#
#  conv1d_12 (Conv1D)          (None, 13, 256)           196864
#
#  batch_normalization_6 (Batc  (None, 13, 256)          1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 13, 256)           0
#
#  max_pooling1d_5 (MaxPooling  (None, 6, 256)           0
#  1D)
#
#  reshape (Reshape)           (None, 1, 1536)           0
#
#  dropout (Dropout)           (None, 1, 1536)           0
#
#  gru (GRU)                   (None, 1536)              14164992
#
#  dense (Dense)               (None, 192)               295104
#
#  dense_1 (Dense)             (None, 5)                 965
#
# =================================================================
# Total params: 15,369,861
# Trainable params: 15,368,005
# Non-trainable params: 1,856
# _________________________________________________________________

# %%
lefms.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
)

# %% [markdown]
# # train, test, validation data 나누기

# %%
# Train
X_train = tf.convert_to_tensor(npx)
X_train = tf.reshape(X_train, [73287, 428, 1])

y_train = tf.convert_to_tensor(npy)
print("X_train shape : ",X_train.shape)
print("y_train shape",y_train.shape)

# Validation
X_vali = tf.convert_to_tensor(npx_vali)
X_vali = tf.reshape(X_vali, [11913, 428, 1])

y_vali = tf.convert_to_tensor(npy_vali)

print("X_validation shape : ", X_vali.shape)
print("y_validation shape : ", y_vali.shape)

# Test
X_test = tf.convert_to_tensor(npx_test)
X_test = tf.reshape(X_test, [24185, 428, 1])

y_test = tf.convert_to_tensor(npy_test)
print("X_test shape : ", X_test.shape)
print("y_test shape : ", y_test.shape)
# Out:
# X_train shape :  (73287, 428, 1)
# y_train shape (73287, 5)
# X_validation shape :  (11913, 428, 1)
# y_validation shape :  (11913, 5)
# X_test shape :  (24185, 428, 1)
# y_test shape :  (24185, 5)

# %% [markdown]
# ### 콜백 설정

# %%
# 콜백 설정
outDir = './cheakpoint/lefms_model/' # 이 경로에 best 모델이 저장된다.
model_names = outDir + 'weights-{val_accuracy:.4f}.h5'
def get_callbacks(patience = 50):
    
    earlystop = EarlyStopping(monitor='val_accuracy', min_delta=0.0001, patience=patience)
  
    model_checkpoint = ModelCheckpoint(model_names, monitor='val_accuracy', verbose=1, save_best_only=True, period = 1)
  
    # callbacks = [earlystop, model_checkpoint]     # earlystop 사용하고 싶으면 이거 풀고 아래꺼 주석 처리
    callbacks = [model_checkpoint]

    return callbacks

# %% [markdown]
# # 학습하기

# %%
callbacks = get_callbacks()

lefms_hist = lefms.fit(X_train, y_train, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCH, 
                        validation_data=(X_vali, y_vali),
                        callbacks = [callbacks])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/200
# 573/573 [==============================] - ETA: 0s - loss: 0.2176 - accuracy: 0.9352
# Epoch 1: val_accuracy improved from -inf to 0.89264, saving model to ./cheakpoint/lefms_model\weights-0.8926.h5
# 573/573 [==============================] - 187s 322ms/step - loss: 0.2176 - accuracy: 0.9352 - val_loss: 0.4938 - val_accuracy: 0.8926
# Epoch 2/200
# 573/573 [==============================] - ETA: 0s - loss: 0.1301 - accuracy: 0.9580
# Epoch 2: val_accuracy did not improve from 0.89264
# 573/573 [==============================] - 176s 308ms/step - loss: 0.1301 - accuracy: 0.9580 - val_loss: 0.5814 - val_accuracy: 0.8926
# Epoch 3/200
# 573/573 [==============================] - ETA: 0s - loss: 0.1127 - accuracy: 0.9648
# Epoch 3: val_accuracy improved from 0.89264 to 0.90380, saving model to ./cheakpoint/lefms_model\weights-0.9038.h5
# 573/573 [==============================] - 176s 307ms/step - loss: 0.1127 - accuracy: 0.9648 - val_loss: 0.5187 - val_accuracy: 0.9038
# Epoch 4/200
# 573/573 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9680
# Epoch 4: val_accuracy did not improve from 0.90380
# 573/573 [==============================] - 175s 306ms/step - loss: 0.1018 - accuracy: 0.9680 - val_loss: 0.7478 - val_accuracy: 0.8879
# Epoch 5/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0951 - accuracy: 0.9703
# Epoch 5: val_accuracy did not improve from 0.90380
# 573/573 [==============================] - 181s 317ms/step - loss: 0.0951 - accuracy: 0.9703 - val_loss: 0.5534 - val_accuracy: 0.9000
# Epoch 6/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0897 - accuracy: 0.9722
# Epoch 6: val_accuracy did not improve from 0.90380
# 573/573 [==============================] - 175s 305ms/step - loss: 0.0897 - accuracy: 0.9722 - val_loss: 0.6750 - val_accuracy: 0.8989
# Epoch 7/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9738
# Epoch 7: val_accuracy did not improve from 0.90380
# 573/573 [==============================] - 180s 313ms/step - loss: 0.0849 - accuracy: 0.9738 - val_loss: 0.6329 - val_accuracy: 0.8522
# Epoch 8/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0814 - accuracy: 0.9738
# Epoch 8: val_accuracy did not improve from 0.90380
# 573/573 [==============================] - 194s 338ms/step - loss: 0.0814 - accuracy: 0.9738 - val_loss: 0.5597 - val_accuracy: 0.9025
# Epoch 9/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0763 - accuracy: 0.9758
# Epoch 9: val_accuracy did not improve from 0.90380
# 573/573 [==============================] - 189s 329ms/step - loss: 0.0763 - accuracy: 0.9758 - val_loss: 0.6070 - val_accuracy: 0.8780
# Epoch 10/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9762
# Epoch 10: val_accuracy did not improve from 0.90380
# 573/573 [==============================] - 195s 340ms/step - loss: 0.0739 - accuracy: 0.9762 - val_loss: 0.6130 - val_accuracy: 0.8985
# Epoch 11/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9773
# Epoch 11: val_accuracy did not improve from 0.90380
# 573/573 [==============================] - 194s 339ms/step - loss: 0.0712 - accuracy: 0.9773 - val_loss: 0.6479 - val_accuracy: 0.8865
# Epoch 12/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 0.9778
# Epoch 12: val_accuracy improved from 0.90380 to 0.90951, saving model to ./cheakpoint/lefms_model\weights-0.9095.h5
# 573/573 [==============================] - 199s 347ms/step - loss: 0.0686 - accuracy: 0.9778 - val_loss: 0.5096 - val_accuracy: 0.9095
# Epoch 13/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9790
# Epoch 13: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 200s 349ms/step - loss: 0.0654 - accuracy: 0.9790 - val_loss: 0.7541 - val_accuracy: 0.8906
# Epoch 14/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9793
# Epoch 14: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 184s 321ms/step - loss: 0.0631 - accuracy: 0.9793 - val_loss: 0.6714 - val_accuracy: 0.8985
# Epoch 15/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9806
# Epoch 15: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 181s 315ms/step - loss: 0.0613 - accuracy: 0.9806 - val_loss: 0.6337 - val_accuracy: 0.8966
# Epoch 16/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0614 - accuracy: 0.9804
# Epoch 16: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 180s 315ms/step - loss: 0.0614 - accuracy: 0.9804 - val_loss: 0.5982 - val_accuracy: 0.9046
# Epoch 17/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9816
# Epoch 17: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 186s 325ms/step - loss: 0.0574 - accuracy: 0.9816 - val_loss: 0.5809 - val_accuracy: 0.8996
# Epoch 18/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9823
# Epoch 18: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 184s 321ms/step - loss: 0.0549 - accuracy: 0.9823 - val_loss: 0.7462 - val_accuracy: 0.8864
# Epoch 19/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9823
# Epoch 19: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 184s 321ms/step - loss: 0.0549 - accuracy: 0.9823 - val_loss: 0.7695 - val_accuracy: 0.8688
# Epoch 20/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9825
# Epoch 20: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 184s 321ms/step - loss: 0.0517 - accuracy: 0.9825 - val_loss: 0.7090 - val_accuracy: 0.8984
# Epoch 21/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0498 - accuracy: 0.9837
# Epoch 21: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 185s 322ms/step - loss: 0.0498 - accuracy: 0.9837 - val_loss: 0.7033 - val_accuracy: 0.9020
# Epoch 22/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9842
# Epoch 22: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 180s 315ms/step - loss: 0.0489 - accuracy: 0.9842 - val_loss: 0.6220 - val_accuracy: 0.8973
# Epoch 23/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9841
# Epoch 23: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 175s 306ms/step - loss: 0.0480 - accuracy: 0.9841 - val_loss: 0.7822 - val_accuracy: 0.8832
# Epoch 24/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0475 - accuracy: 0.9845
# Epoch 24: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 179s 313ms/step - loss: 0.0475 - accuracy: 0.9845 - val_loss: 0.6789 - val_accuracy: 0.9011
# Epoch 25/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9848
# Epoch 25: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 179s 313ms/step - loss: 0.0463 - accuracy: 0.9848 - val_loss: 0.6173 - val_accuracy: 0.9051
# Epoch 26/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.9853
# Epoch 26: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 179s 313ms/step - loss: 0.0441 - accuracy: 0.9853 - val_loss: 0.8632 - val_accuracy: 0.8778
# Epoch 27/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0433 - accuracy: 0.9854
# Epoch 27: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 178s 311ms/step - loss: 0.0433 - accuracy: 0.9854 - val_loss: 0.6555 - val_accuracy: 0.8999
# Epoch 28/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0413 - accuracy: 0.9866
# Epoch 28: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 179s 313ms/step - loss: 0.0413 - accuracy: 0.9866 - val_loss: 0.7141 - val_accuracy: 0.9010
# Epoch 29/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0414 - accuracy: 0.9861
# Epoch 29: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 178s 310ms/step - loss: 0.0414 - accuracy: 0.9861 - val_loss: 0.7645 - val_accuracy: 0.8958
# Epoch 30/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0389 - accuracy: 0.9869
# Epoch 30: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 169s 295ms/step - loss: 0.0389 - accuracy: 0.9869 - val_loss: 0.5984 - val_accuracy: 0.9036
# Epoch 31/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9874
# Epoch 31: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 168s 292ms/step - loss: 0.0384 - accuracy: 0.9874 - val_loss: 0.7756 - val_accuracy: 0.8816
# Epoch 32/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9882
# Epoch 32: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 167s 292ms/step - loss: 0.0363 - accuracy: 0.9882 - val_loss: 0.8875 - val_accuracy: 0.8718
# Epoch 33/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9872
# Epoch 33: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 167s 291ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.7144 - val_accuracy: 0.8958
# Epoch 34/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9886
# Epoch 34: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 167s 291ms/step - loss: 0.0346 - accuracy: 0.9886 - val_loss: 0.7868 - val_accuracy: 0.9026
# Epoch 35/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9885
# Epoch 35: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 167s 292ms/step - loss: 0.0341 - accuracy: 0.9885 - val_loss: 1.0369 - val_accuracy: 0.8936
# Epoch 36/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9884
# Epoch 36: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 167s 292ms/step - loss: 0.0346 - accuracy: 0.9884 - val_loss: 0.6485 - val_accuracy: 0.9036
# Epoch 37/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9892
# Epoch 37: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 168s 292ms/step - loss: 0.0326 - accuracy: 0.9892 - val_loss: 0.9809 - val_accuracy: 0.8989
# Epoch 38/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9890
# Epoch 38: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 168s 294ms/step - loss: 0.0322 - accuracy: 0.9890 - val_loss: 1.0349 - val_accuracy: 0.8966
# Epoch 39/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9895
# Epoch 39: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 168s 294ms/step - loss: 0.0324 - accuracy: 0.9895 - val_loss: 0.8042 - val_accuracy: 0.8998
# Epoch 40/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9902
# Epoch 40: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 168s 294ms/step - loss: 0.0298 - accuracy: 0.9902 - val_loss: 0.8139 - val_accuracy: 0.8938
# Epoch 41/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9903
# Epoch 41: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 169s 296ms/step - loss: 0.0280 - accuracy: 0.9903 - val_loss: 0.8324 - val_accuracy: 0.9004
# Epoch 42/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9906
# Epoch 42: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 169s 295ms/step - loss: 0.0284 - accuracy: 0.9906 - val_loss: 0.9937 - val_accuracy: 0.8963
# Epoch 43/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9904
# Epoch 43: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 170s 296ms/step - loss: 0.0289 - accuracy: 0.9904 - val_loss: 0.7616 - val_accuracy: 0.9048
# Epoch 44/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9906
# Epoch 44: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 170s 296ms/step - loss: 0.0281 - accuracy: 0.9906 - val_loss: 1.1148 - val_accuracy: 0.8988
# Epoch 45/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9909
# Epoch 45: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 171s 298ms/step - loss: 0.0277 - accuracy: 0.9909 - val_loss: 1.0401 - val_accuracy: 0.8983
# Epoch 46/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9912
# Epoch 46: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 170s 297ms/step - loss: 0.0260 - accuracy: 0.9912 - val_loss: 0.8875 - val_accuracy: 0.8957
# Epoch 47/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9915
# Epoch 47: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 171s 298ms/step - loss: 0.0253 - accuracy: 0.9915 - val_loss: 1.1875 - val_accuracy: 0.8738
# Epoch 48/200
# 573/573 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9918
# Epoch 48: val_accuracy did not improve from 0.90951
# 573/573 [==============================] - 171s 298ms/step - loss: 0.0246 - accuracy: 0.9918 - val_loss: 0.7651 - val_accuracy: 0.9041
# Epoch 49/200
# 460/573 [=======================>......] - ETA: 33s - loss: 0.0257 - accuracy: 0.9915
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_22952/3188329247.py in <module>
#       1 callbacks = get_callbacks()
#       2
# ----> 3 lefms_hist = lefms.fit(X_train, y_train,
#       4                         batch_size=BATCH_SIZE,
#       5                         epochs=EPOCH,
#
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# # 결과 시각화 하기

# %%
# 학습 된 모델의 학습 과정 시각화
import matplotlib.pyplot as plt
def plot_model__hist(hist):
    path = './cheakpoint/lefms/' # loss, accuracy 그래프 저장할 path
    createDirectory(path)

    # loss 추이 그래프로 그려서 저장
    plt.figure(figsize=(6,6))
    plt.style.use("ggplot")
    plt.plot(hist.history['loss'], color='b', label="Training loss")
    plt.plot(hist.history['val_loss'], color='r', label="Validation loss")
    plt.savefig(path + 'model_loss_hist.png')
    plt.legend()
    plt.show()

    # accuracy 추이 그래프로 그려서 저장
    plt.figure(figsize=(6,6))
    plt.style.use("ggplot")
    plt.plot(hist.history['accuracy'], color='b', label="Training accuracy")
    plt.plot(hist.history['val_accuracy'], color='r',label="Validation accuracy")
    plt.savefig(path + 'model_loss_hist.png')
    plt.legend(loc = "lower right")
    plt.show()

# %%
plot_model__hist(lefms_hist)
loss,acc = lefms.evaluate(X_test, y_test, verbose=2)
print("multi_model의 정확도: {:5.2f}%".format(100*acc))
print("multi_model의 Loss: {}".format(loss))

# %% [markdown]
# # 모델 불러와서 confusion matrix 그리기

# %%
# 모델 불러오기
reconstructed_model = keras.models.load_model("./cheakpoint/lefms_model/weights-0.9924.h5")

# %%
# 예측값 얻기
y_pred = reconstructed_model.predict(X_test)

# %%
# one hat encoding 를 하나의 변수로 바꾸기
new_y= []
for val in y_test:
    max = 0
    cnt = 0
    for idx, num in enumerate(val):
        if max < num:
            max = num
            cnt = idx + 1
    new_y.append(cnt)

# %%
# one hat encoding 를 하나의 변수로 바꾸기
new_y_pred = []
for val in y_pred:
    max = 0
    cnt = 0
    for idx, num in enumerate(val):
        if max < num:
            max = num
            cnt = idx + 1
    new_y_pred.append(cnt)

# %%
# 최종 정확도 산출
score = reconstructed_model.evaluate(X_test, y_test, verbose=1)
print('정답률 = ', score[1],'loss=', score[0])

# %% [markdown]
# ### confusion matrix 그리기

# %%
# 개수 버전
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns

cm2 = confusion_matrix(new_y, new_y_pred)
sns.heatmap(cm2, annot = True, fmt = 'd', cmap= 'Reds')
plt.xlabel('predict')
plt.ylabel('real')
plt.xticks([0.5, 1.5, 2.5, 3.5, 4.5], ['0 = N', '1 = S', '2 = V', '3 = F', '4 = Q'])
plt.yticks([0.5, 1.5, 2.5, 3.5, 4.5], ['0 = N', '1 = S', '2 = V', '3 = F', '4 = Q'])
plt.show()

# %%
# percentile 버전
total = np.sum(cm2, axis=1)
cm2_percentile = cm2/total[:,None]
sns.heatmap(np.round(cm2_percentile,3), annot = True, cmap= 'Reds')
plt.xlabel('predict')
plt.ylabel('real')
plt.xticks([0.5, 1.5, 2.5, 3.5, 4.5], ['0 = N', '1 = S', '2 = V', '3 = F', '4 = Q'])
plt.yticks([0.5, 1.5, 2.5, 3.5, 4.5], ['0 = N', '1 = S', '2 = V', '3 = F', '4 = Q'])
plt.show()

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(new_y, new_y_pred)

# %%
# classification_report 그리기
from sklearn.metrics import classification_report
target_names = ['0 = N', '1 = S', '2 = V', '3 = F', '4 = Q']
print(classification_report(new_y, new_y_pred, target_names=target_names))
